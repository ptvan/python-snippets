# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read in data
cottage = pd.read_csv("datasets/cozycottage/cozycottage_data.csv")

# %%
# take a look
cottage.head()
# Out:
#              address   neighborhood  listed_price  house_sqft  lot_sqft  \
# 0  14556 20th Ave NE     Briarcrest        568000        1570      8245
# 1  15340 Stone Ave N       Parkwood        600000        1770      8595
# 2   14342 Wayne Pl N       Parkwood        590000        1550      5250
# 3  13339 11th Ave NE  Olympic Hills        585000        1980      7500
# 4  12503 14th Ave NE      Pinehurst        618000        1880      5111
#
#    n_bedrooms  n_bathrooms date_seen
# 0           3         2.00   8/18/19
# 1           3         1.75   8/18/19
# 2           3         2.00   8/17/19
# 3           4         1.75   8/17/19
# 4           4         1.75   8/17/19

# %%
# basic plots
sns.set_style("whitegrid")
fig, ax =plt.subplots(1,2)

price_by_neighborhood = sns.boxplot(x=cottage["neighborhood"], y=cottage["listed_price"], ax=ax[0])
price_by_neighborhood.set_xticklabels(price_by_neighborhood.get_xticklabels(), rotation=45, horizontalalignment='right')

bedrooms_vs_price = sns.boxplot(x=cottage["n_bedrooms"], y=cottage["listed_price"], ax=ax[1])
# fig.show()

# display(price_by_neighborhood)
# display(bedrooms_vs_price)
