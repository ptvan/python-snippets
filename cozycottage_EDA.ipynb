# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read in data
houses = pd.read_csv("~/working/datasets/house_prices/Seattle_house_listings.csv")

# %%
# take a look
houses.head()
# Out:
#              address   neighborhood  listed_price  house_sqft  lot_sqft  \
# 0  15340 Stone Ave N       Parkwood        600000        1770      8595
# 1   14342 Wayne Pl N       Parkwood        590000        1550      5250
# 2  13339 11th Ave NE  Olympic Hills        585000        1980      7500
# 3  12503 14th Ave NE      Pinehurst        618000        1880      5111
# 4  10005 21st Ave NE    Morningside        579000        1780      6533
#
#    n_bedrooms  n_bathrooms date_seen
# 0           3         1.75   8/18/19
# 1           3         2.00   8/17/19
# 2           4         1.75   8/17/19
# 3           4         1.75   8/17/19
# 4           4         1.75   8/17/19

# %%
# exploratory analyses
houses[houses["n_bedrooms"] > 1].groupby("neighborhood").listed_price.mean()
# Out:
# neighborhood
# Ballard            600000.000000
# Broadview          575000.000000
# Bryant             525000.000000
# Cedar Park         539000.000000
# Crown Hill         560000.000000
# Greenwood          539000.000000
# Licton Springs     500000.000000
# Mapleleaf          577800.000000
# Meadowbrook        575000.000000
# Morningside        579000.000000
# Olympic Hills      608333.333333
# Parkwood           595000.000000
# Pinehurst          583600.000000
# Victory Heights    588333.333333
# Wedgwood           600000.000000
# Name: listed_price, dtype: float64

# %%
# basic plots
sns.set_style("whitegrid")
fig, ax =plt.subplots(1,2)

price_by_neighborhood = sns.boxplot(x=houses["neighborhood"], y=houses["listed_price"], ax=ax[0])
price_by_neighborhood.set_xticklabels(price_by_neighborhood.get_xticklabels(), rotation=45, horizontalalignment='right')

bedrooms_vs_price = sns.boxplot(x=houses["n_bedrooms"], y=houses["listed_price"], ax=ax[1])
# fig.show()

# display(price_by_neighborhood)
# display(bedrooms_vs_price)
# Out:
# /var/folders/73/pt705bkj1fj6qx99c13xp7540000gn/T/ipykernel_63472/2522438253.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   price_by_neighborhood.set_xticklabels(price_by_neighborhood.get_xticklabels(), rotation=45, horizontalalignment='right')
